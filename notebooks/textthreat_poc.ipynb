# %% [markdown]
# # TextThreat PoC Notebook
#
# The reproducible implementation lives in `src/textthreat/` and `scripts/`. This notebook is a lightweight companion for running the thesis proof-of-concept commands from Jupyter.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
ROOT

# %%
# %cd $ROOT
# !python scripts/smoke_test.py

# %% [markdown]
# For full training runs, use the terminal or Colab:
#
# ```bash
# python -m src.textthreat.train_svm
# python -m src.textthreat.train_distilbert --task jigsaw --epochs 1
# python -m src.textthreat.train_distilbert --task dreaddit --epochs 1
# ```
